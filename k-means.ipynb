# %%
import numpy as np # linear algebra


import os
for dirname, _, filenames in os.walk(''):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

from sklearn.cluster import KMeans
from collections import defaultdict
import io

# %%
def file_preprocess(file_name, nwords):
  '''
  function to readtext file and process it to create data for clustering
  
  RETURNS: numpy array of vector dimension and list of words
  '''
  np_arrays = []
  wordlist = []
  with io.open(file_name, mode='r', encoding='utf-8') as f:
    #print("len" , len(f.readlines()))
    for index, line in enumerate(f):
      tokens = line.split()
      wordlist.append(tokens[0])
      np_arrays.append( np.array([float(i) for i in tokens[1:]]) )

      if index == nwords:
        return np.array( np_arrays ), wordlist

  return np.array( np_arrays ), wordlist

# %%
def assign_word2cluster(word_list, cluster_labels):
  '''
  RETURNS: dict {"cluster":[words  assigend to cluster]}
  '''
  cluster_to_words = defaultdict(list)
  for index, cluster in enumerate(cluster_labels):
    cluster_to_words[ cluster ].append( word_list[index] )
  return cluster_to_words

# %%
if __name__ == "__main__":
    

  cluster_data_file = "clustering_data.txt" 

  #Number of words to analyse according to memory availability
  n_words = 3000 # Number of words to analyse according to memory availability
  reduction_factor =.1  # Amount of dimension reduction {0,1}
  n_clusters = int( n_words * reduction_factor ) # Number of clusters to make
  cluster_data, wordlist = file_preprocess(cluster_data_file, nwords = n_words)
  
  kmeans_model = KMeans(init='k-means++', n_clusters=n_clusters, n_init=15,random_state=1,max_iter=500,verbose=0)
  kmeans_model.fit(cluster_data)

  cluster_labels  = kmeans_model.labels_ #returns all cluster number assigned to each word respectively
  cluster_to_words  = assign_word2cluster(wordlist, cluster_labels)
  #saving output in outut.text file
  with io.open("output.txt",mode='w+',encoding="UTF-8") as file:
    for key in sorted(cluster_to_words.keys()) :
        file.writelines("Cluster "+str(key) +" :: "+ "|".join( k for k in cluster_to_words[key])+"\n")
        print("Cluster "+str(key) , " :: " , "|".join( k for k in cluster_to_words[key]))
    file.close()
# Out:
# Cluster 0  ::  china|chinese|korea|taiwan|beijing|vietnam
# Cluster 1  ::  older|generation
# Cluster 2  ::  cut|fall|raised|drop|reserve|grew|fed|drew|marks|falls|sharp
# Cluster 3  ::  lead|key|ahead|failed|helped|effort|chance|reach|success|hopes|challenge|target|opportunity|managed|advantage|advance|closer|leads|surprise|secure|chances|crucial
# Cluster 4  ::  %|40|60|70|80|35|45|90|65|32|33|36|75|34|44|38|37|48
# Cluster 5  ::  i|my|'re|me|'m|am|'d|guy|guys|everybody
# Cluster 6  ::  interest|job|gain|retirement|returns|employment
# Cluster 7  ::  title|grand|super|classic|titles
# Cluster 8  ::  already|remain|remains|throughout|remained|mostly|largely|mainly|presence|increasingly|heavily|abroad|elsewhere
# Cluster 9  ::  live|!|love|fans|watch|happy|kids|walk|watching|dream|fun
# Cluster 10  ::  its|itself|whole|create|entire|complex|fully|structure|completely|creating|core|creation
# Cluster 11  ::  held|moved|division|served|opened|joined|camp|formed|placed|entered|serving|headed|branch|newly|settled
# Cluster 12  ::  role|launched|aimed|backed|supporting
# Cluster 13  ::  director|research|science|dr.|environmental|expert
# Cluster 14  ::  house|security|office|federal|department|administration|board|commission|post|authority|mayor|headquarters|interior|offices
# Cluster 15  ::  we|n't|you|if|do|get|going|go|see|want|your|'ll|ca|let|sure|wo
# Cluster 16  ::  bill|david|mark|lee|smith|jones|williams|johnson|van|co|jordan|jackson|davis|agent|mr.|frank|jack|kennedy|grant|miller|taylor|howard|lewis|wilson|ben|bell
# Cluster 17  ::  italy|spain|italian|spanish|madrid|rome|milan
# Cluster 18  ::  free|provide|allowed|needed|allow|safety|required|additional|necessary|carry|measure|standards|extra|intended|allowing|providing|permanent|require|existing|check|transfer|allows|limit|entry|requires
# Cluster 19  ::  right|body|hand|cross|hands|arms|holding|eye|eyes|broken|clean|pair|arm|lay
# Cluster 20  ::  officials|foreign|crisis|meanwhile|warned|blamed|worried
# Cluster 21  ::  year|2006|2000|2004|2005|2001|2003|2002|1998|1996|1999|1994|1997|1995|1993|officially
# Cluster 22  ::  nuclear|iran|weapons|iranian|missile|tehran
# Cluster 23  ::  series|released|release|original|video|produced|records|version|recorded|features|performed|featured|studio|feature|tracks|recording
# Cluster 24  ::  germany|sweden|netherlands|switzerland|austria|norway|belgium
# Cluster 25  ::  caused|damage|worst|storm|massive|affected|disaster|toll|severe|hurricane|collapse|causing
# Cluster 26  ::  record|round|no.|runs|finished|double|straight|finish|spot|hits|ranked|bottom|consecutive|woods|tied|tie|hole
# Cluster 27  ::  work|own|program|working|process|worked|programs|practice|successful|complete|conducted|begun
# Cluster 28  ::  or|such|these|different|form|similar|common|example|various|related|usually|certain|particular|produce|specific|variety|forms|elements|typically|multiple|types
# Cluster 29  ::  though|yet|ever|clear|believe|fact|question|idea|reason|perhaps|concerned|certainly|clearly|nor|neither|believes|seriously|doubt|indeed|proved|prove|ultimately
# Cluster 30  ::  said|told|official|spokesman|ministry|reporters|afp|quoted|spokeswoman|embassy|xinhua
# Cluster 31  ::  market|prices|price|dollar|markets|analysts|currency|crude|dealers
# Cluster 32  ::  access|travel|source|search|direct|sites|directly|contact|via|controlled|links|connection|express|link|flow
# Cluster 33  ::  miles|kilometers|km|mile
# Cluster 34  ::  campaign|passed|reform|declared|re|convention|adopted|reforms|presidency|coup
# Cluster 35  ::  construction|domestic|commercial|limited|operating|transport|capacity|overseas|transportation|distribution|operated|delivery|expanded
# Cluster 36  ::  force|training|staff|operations|operation|officers|unit|guard|units|positions|personnel|combat|civilian|task|enforcement|duty|corps
# Cluster 37  ::  a|'s|is|an|another|whose
# Cluster 38  ::  big|start|taking|coming|stop|turn|break|strike|drive|tough|fast|save|push|slow|pick|hurt|trouble|putting|keeping|bringing|pace|moves|turning|quick|pushed|driven|pull
# Cluster 39  ::  she|her|wife|woman|mother|daughter|married|husband|marriage|mary|sister|ms.|lady|actress|herself
# Cluster 40  ::  sides|discuss|diplomatic|dialogue|discussed|differences|stressed
# Cluster 41  ::  including|include|special|list|included|currently|class|includes|addition|provided|cover|separate|regular|primary|active|listed|offers|provides|numerous|combined|minor|plus|selected|notable|primarily|serves|category|nationwide
# Cluster 42  ::  death|died|deaths|birth
# Cluster 43  ::  indonesia|thailand|malaysia|thai|nigeria|zimbabwe|myanmar|kenya|bangladesh
# Cluster 44  ::  action|response|measures|immediate|criticism|actions|warning|reaction
# Cluster 45  ::  money|pay|jobs|paid|raise|cash|receive|millions|benefits|spend|raising|benefit|funding|coverage|paying
# Cluster 46  ::  last|week|tuesday|wednesday|monday|thursday|friday|month|sunday|saturday|earlier|announcement
# Cluster 47  ::  accused|charged|denied|admitted|allegedly
# Cluster 48  ::  was|he|his|had|after|when|him|before|then|later|until|took|came|again|went|once|having|started|gave|sent|soon|saw|returned|brought|spent|forced|immediately|quickly|eventually|leaving|finally|twice|shortly|returning
# Cluster 49  ::  game|best|play|played|career|players|player|playing|plays
# Cluster 50  ::  percent|rate|higher|average|low|lower|rates|rise|compared|rising|decline|expectations|percentage
# Cluster 51  ::  rebels|taliban|militants|rebel|civilians|militant
# Cluster 52  ::  center|centre|facility|campus|centers
# Cluster 53  ::  company|based|business|companies|industry|management|firm|consumer|businesses|corporate|executives|firms|marketing|commerce|advertising|venture
# Cluster 54  ::  countries|nations|africa|african|u.n.|un
# Cluster 55  ::  society|language|religious|traditional|culture|cultural|religion|tradition
# Cluster 56  ::  funds|value|property|account|trust|assets|accounts|stake
# Cluster 57  ::  asked|call|talk|heard|ask|answer|speak|hear|asking|telling
# Cluster 58  ::  plant|plants|farm|forest|farmers|grow|fields|tree|trees
# Cluster 59  ::  de|la|le
# Cluster 60  ::  island|sea|coast|pacific|gulf|earth|islands|atlantic|ocean|waters
# Cluster 61  ::  president|general|chief|secretary|executive|chairman|vice|deputy|affairs|ambassador|representative|commissioner
# Cluster 62  ::  1|10|2|3|20|15|30|4|11|12|5|18|6|25|7|8|14|13|16|17|9|24|19|22|21|23|26|28|27|31|29|1/2|respectively
# Cluster 63  ::  news|press|media|daily|newspaper|newspapers|weekly|website
# Cluster 64  ::  $|million|billion|dollars|worth|dlrs|euros
# Cluster 65  ::  york|washington|street|london|manhattan
# Cluster 66  ::  at|where|city|around|along|main|across|site|outside|land|places|nearby|beach|location|surrounding
# Cluster 67  ::  ship|crew|carrying|passengers|rescue|fly|boat|pilot
# Cluster 68  ::  military|army|forces|troops|soldiers
# Cluster 69  ::  committee|congress|elected|assembly|representatives|lawmakers|congressional|legislative|legislature
# Cluster 70  ::  are|have|were|more|about|there|all|other|than|some|most|many|still|those|several|number|among|few|least|far|others|almost|cases|numbers|ones|none
# Cluster 71  ::  government|support|efforts|attempt|seeking|urged|protect|governments|seek|sought|promised|helping|powers|allies|demands|attempts
# Cluster 72  ::  white|black|red|green|brown|blue|dark|color|suit|wearing|yellow
# Cluster 73  ::  muslim|jewish|jerusalem|muslims|jews
# Cluster 74  ::  california|texas|florida|bay|jersey|miami|arizona|kansas|colorado|minnesota
# Cluster 75  ::  who|man|young|himself|friends|parents|whom|couple|friend|boy|brothers|learned|younger|tells
# Cluster 76  ::  air|navy|marine|ships|flying|naval|fleet
# Cluster 77  ::  story|character|stories|episode|novel|characters
# Cluster 78  ::  stock|shares|share|index|exchange|investors|trading|stocks
# Cluster 79  ::  majority|labor|conservative|critics|policies|supported|opposed|opinion|liberal|minority|opponents|favor|strongly
# Cluster 80  ::  attack|attacks|terrorism|terrorist|suicide|bombing|terror|plot|qaida|targets|terrorists|bombings
# Cluster 81  ::  whether|change|possible|future|likely|problem|situation|difficult|potential|condition|reasons|solution|possibility|determined|finding|determine|possibly|unlikely
# Cluster 82  ::  total|per|100|nearly|50|200|estimated|500|pounds|300|1,000|meters|approximately|400|tons|150|10,000
# Cluster 83  ::  ''|``|what|?|how|says|does|think|know|...|something|things|why|thing|`|nothing|anything|everything|someone|tell|everyone|knew|anyone|happened|else|wrong|maybe|talking|understand|happen|knows|whatever|remember|yes|exactly
# Cluster 84  ::  they|their|would|could|them|did|make|our|should|take|say|help|come|must|need|might|give|keep|trying|find|able|wanted|try|bring|tried|themselves|unable|learn
# Cluster 85  ::  war|violence|fighting|fight|battle|conflict|ethnic|fought|violent|invasion|struggle|resistance
# Cluster 86  ::  march|june|july|april|september|january|december|october|november|august|february
# Cluster 87  ::  information|internet|data|computer|web|online|software|microsoft|digital|electronic|users|computers|networks
# Cluster 88  ::  closed|morning|session|afternoon|evening|closing|overnight|yesterday
# Cluster 89  ::  democratic|republican|senate|democrats|candidate|republicans|senator|democrat
# Cluster 90  ::  car|cars|train|vehicles|bus|vehicle|driver|driving|truck|passenger
# Cluster 91  ::  disease|flu|virus
# Cluster 92  ::  england|australia|australian|zealand|ireland|irish|cricket|scotland|sydney|wales|manchester
# Cluster 93  ::  the|,|.|of|to|and|in|for|on|with|it|from|but|this|which|one|new|time|only|_|while|now|made|well|both|part|here|same|each|place|times|added|every|today|close|making|together|present|adding|rest|alone
# Cluster 94  ::  police|authorities|arrested|suspected|arrest|journalists|agents|prisoners|suspects|witnesses|seized|suspect|detained
# Cluster 95  ::  art|works|museum|collection|library
# Cluster 96  ::  international|european|europe|eu|britain|euro|greece
# Cluster 97  ::  killed|dead|killing|victims|wounded|missing|bodies|kill|die|soldier|buried|alive
# Cluster 98  ::  iraq|iraqi|afghanistan|baghdad|saddam|afghan|hussein|shiite
# Cluster 99  ::  women|children|men|age|child|female|girl|youth|girls|boys|baby|male
# Cluster 100  ::  production|products|industrial|sector|industries|manufacturing|corporation|factory
# Cluster 101  ::  serbia|croatia|yugoslavia
# Cluster 102  ::  steel|mine|metal|wood|iron
# Cluster 103  ::  issue|policy|issues|legal|questions|review|debate|address|resolution|subject|legislation|dispute|internal|agenda
# Cluster 104  ::  old|family|born|father|son|brother|lived|doctor|sons
# Cluster 105  ::  pennsylvania|massachusetts|michigan|township
# Cluster 106  ::  vote|voters|candidates|votes|polls|voted|voting
# Cluster 107  ::  arafat|sharon|abbas|netanyahu
# Cluster 108  ::  show|appeared|popular|performance|stage|shows|scene|host|voice|shown|cast|picture|appearance|presented|image|audience|background|fox|pictures|screen|fashion|photos|display|theme
# Cluster 109  ::  san|los|francisco|jose|santa|diego|antonio
# Cluster 110  ::  workers|thousands|residents|hundreds|refugees|dozens|visitors|tourists|fled|relatives|gathered
# Cluster 111  ::  charges|investigation|charge|illegal|alleged|corruption|allegations|involving|scandal|fraud|involvement
# Cluster 112  ::  against|lost|loss|losing|draw|defeat|lose|beating
# Cluster 113  ::  members|groups|organization|independent|activities|non|responsible|organizations|agencies|institutions|organized
# Cluster 114  ::  won|win|victory|winning|beat|champion|winner|wins|defeated|defending
# Cluster 115  ::  figure|earned|partner|holds|represented|shared|registered|represents|membership|chosen|recognized|represent
# Cluster 116  ::  world|tour|competition|track|professional|sport|races|racing|clubs|compete|horse|competitive|contest
# Cluster 117  ::  al|islamic|saudi|ali|bin|abu|egyptian|arabia|laden
# Cluster 118  ::  health|hospital|medical|care|medicine
# Cluster 119  ::  buy|sell|selling|sale|customers|consumers|buying|purchase|brand|expensive
# Cluster 120  ::  named|âs|created|established|&|founded|â|â|â|foundation|master|honor|founder|principal
# Cluster 121  ::  murder|convicted|guilty|sentenced
# Cluster 122  ::  baseball|nfl|nba
# Cluster 123  ::  court|case|trial|justice|judge|attorney|lawyer|supreme|filed|appeal|hearing|lawyers|prosecutors|panel|jury|courts|prosecutor|judges|appeals
# Cluster 124  ::  film|movie|stars|films|directed|actor|hollywood|movies|drama|comedy
# Cluster 125  ::  road|route|traffic|highway|roads
# Cluster 126  ::  us|u.s.|united|states|country|american|trade|america|nation|canada
# Cluster 127  ::  minutes|shot|forward|ball|minute|pass|seconds|penalty|missed|leg|shots
# Cluster 128  ::  species|native|fish|wild|animals|bird|animal|dog
# Cluster 129  ::  6-3|6-4
# Cluster 130  ::  mexico|brazil|latin|argentina|mexican|cuba|brazilian|colombia
# Cluster 131  ::  scheduled|sept.|oct.|dec.|jan.|nov.|aug.|feb.
# Cluster 132  ::  church|christian|catholic|roman|pope|holy|bishop
# Cluster 133  ::  decision|issued|claims|refused|settlement|claim|rejected|request|accepted|criticized|insisted|argued|repeatedly|demanded|controversial|dismissed|concluded|publicly
# Cluster 134  ::  republic|poland|czech|ukraine|polish
# Cluster 135  ::  tax|cost|income|spending|costs|amount|insurance|reduce|cuts|taxes|cutting|bills
# Cluster 136  ::  saying|statement|interview|calls|noted|letter|speech|comment|speaking|expressed|message|calling|suggested|spoke|comments|stated|blair|acknowledged|referring|remarks|anonymity|indicated|powell|delivered|statements
# Cluster 137  ::  television|station|radio|tv|network|channel|stations|broadcast|entertainment|cable|satellite
# Cluster 138  ::  border|territory|zone|strip|borders
# Cluster 139  ::  wall|above|feet|below|slightly|upper|length|trim|flat
# Cluster 140  ::  date|word|names|article|note|follows|refer|referred|text|ad|reference
# Cluster 141  ::  into|between|through|within|side|ground|parts|lines|deep|remaining|spread|covered|divided|surface|split|lies|drawn|apart|portion
# Cluster 142  ::  robert|richard|w.|c.|j.|a.|jr.|m.|s.|daniel
# Cluster 143  ::  survey|poll
# Cluster 144  ::  crime|criminal|crimes|committed
# Cluster 145  ::  p.m.|gmt|a.m.
# Cluster 146  ::  up|out|over|down|back|off|home|left|run|put|past|half|got|hit|away|behind|running|turned|kept|broke|ran|fired|stopped|struck|caught|pulled|handed|picked|sending|shut
# Cluster 147  ::  sports|basketball|hockey
# Cluster 148  ::  s|ap|eds|adds|urgent|------|updates
# Cluster 149  ::  budget|deficit|fiscal|monetary
# Cluster 150  ::  important|view|focus|ways|relationship|approach|critical|influence|strategy|interests|views|focused|closely|interested|ideas|changing|challenges
# Cluster 151  ::  as|by|has|been|also|under|being|called|however|known|became|name|although|recently|described|changed|previously|originally|introduced|replaced|widely|initially|replace|unlike
# Cluster 152  ::  economic|global|asia|climate|worldwide
# Cluster 153  ::  become|less|often|considered|especially|growing|poor|sometimes|particularly|natural|experience|quality|generally|becoming|rich|highly|mixed|relatively|rare|friendly|extremely|grown|frequently
# Cluster 154  ::  head|member|senior|appointed|assistant|acting|junior
# Cluster 155  ::  community|housing|rural|urban|communities
# Cluster 156  ::  drug|drugs|aids
# Cluster 157  ::  central|region|province|regional|regions|neighboring
# Cluster 158  ::  will|move|return|continue|meet|hold|hope|decided|leave|wants|step|stay|begin|sign|ready|join|expect|send|prepared|accept|steps|decide|waiting|unless|agree|willing|enter|hoped|wait|hoping
# Cluster 159  ::  team|league|club|football|coach|teams|soccer|squad|rugby
# Cluster 160  ::  food|equipment|facilities|materials|supplies
# Cluster 161  ::  river|lake|valley|mountain|mountains|mount
# Cluster 162  ::  found|taken|involved|evidence|believed|claimed|carried|ordered|identified|secret|discovered|apparently|orders|linked|removed|revealed|reportedly|unknown
# Cluster 163  ::  injured|suffered|injury|injuries|suffering|pain
# Cluster 164  ::  real|makes|comes|takes|goes|appears|gets|easy|gives|looks|leaves|miss|becomes|perfect|favorite|turns
# Cluster 165  ::  sen.|r|d|rep.
# Cluster 166  ::  used|use|system|using|available|light|standard|product|sound|type|optional|basic|uses|simple|code|machine|alternative|memory|content|applied
# Cluster 167  ::  built|square|bridge|avenue|palace|tower
# Cluster 168  ::  power|control|needs|progress|greater|confidence|improve|ability|responsibility|ensure|respect|effective|strength|maintain|improved|stability|strategic|commitment|balance|importance|establish|achieve|exercise|stronger
# Cluster 169  ::  water|hot|add|ice|cold|fresh|heat|wine|salt
# Cluster 170  ::  former|leader|retired|fellow|veteran|ex|politician
# Cluster 171  ::  minister|prime|premier
# Cluster 172  ::  ban|sanctions|banned|imposed
# Cluster 173  ::  1st|2nd
# Cluster 174  ::  movement|independence|communist|democracy|revolution|peaceful
# Cluster 175  ::  meeting|conference|summit|ministers|meetings|delegation|forum
# Cluster 176  ::  signed|contract|draft|suspended|signing
# Cluster 177  ::  nato|kosovo|serb|bosnia|bosnian|serbs
# Cluster 178  ::  details|material|paper|documents|items|contains|document|contained
# Cluster 179  ::  &amp;|inc.|corp.|co.|maker
# Cluster 180  ::  michael|paul|peter|andrew|stephen|patrick
# Cluster 181  ::  season|seasons
# Cluster 182  ::  british|french|france|german|paris|dutch|swiss|jean|swedish
# Cluster 183  ::  development|project|build|projects|resources|planning|environment|developing|develop|promote|tourism|expand|opportunities|partnership|initiative|programme|infrastructure
# Cluster 184  ::  angeles|atlanta|boston|chicago|houston|philadelphia|detroit|usa|toronto|seattle|dallas|giants
# Cluster 185  ::  building|homes|buildings|houses|destroyed|damaged
# Cluster 186  ::  aircraft|flight|plane|flights|planes
# Cluster 187  ::  bank|financial|investment|fund|finance|analyst|securities|banking
# Cluster 188  ::  golf|tennis
# Cluster 189  ::  group|top|major|led|leading|biggest|pro|powerful|alliance|rival|wing|prominent|dominated
# Cluster 190  ::  officer|commander|command|gen.
# Cluster 191  ::  (|)|:|;|/|=|x|m|t|.....|[
# Cluster 192  ::  south|north|west|east|western
# Cluster 193  ::  two|three|four|five|six|seven|eight|nine|ten|dozen|scores
# Cluster 194  ::  heart|blood|cancer|cell|surgery|cells|brain
# Cluster 195  ::  people|population|living|americans|families|lives|citizens|individuals|immigrants|households
# Cluster 196  ::  given|order|received|current|full|term|position|personal|person|terms|upon|giving|serve|status|individual|basis|thus|choice|difference|count|granted|receiving
# Cluster 197  ::  fire|bomb|incident|shooting|occurred|accident|crash|explosion|blast
# Cluster 198  ::  national|union|association|canadian|federation
# Cluster 199  ::  philippines|indonesian|philippine
# Cluster 200  ::  decades|era|decade|1980s|1990s|1970s|1960s
# Cluster 201  ::  history|century|modern|historic|famous|historical|ancient|20th
# Cluster 202  ::  test|tests|testing
# Cluster 203  ::  so|like|just|even|way|much|very|good|too|never|little|better|'ve|lot|enough|really|hard|look|always|thought|looking|getting|doing|kind|bad|feel|seems|felt|gone|bit|moment|mind|quite|seemed|looked|seem|pretty|thinking|feeling|sort|seeing|worse
# Cluster 204  ::  oil|energy|gas|fuel|supply|chemical|electricity
# Cluster 205  ::  points|goal|scored|goals|score|yards|scoring|innings
# Cluster 206  ::  king|ii|royal|prince|kingdom|queen|lord|empire
# Cluster 207  ::  russia|russian|soviet|moscow|berlin|putin|yeltsin
# Cluster 208  ::  university|institute|professor|studies|academy|studied
# Cluster 209  ::  magazine|journal|writer|author|editor|cox|writers
# Cluster 210  ::  festival|arts|theater|theatre|opera
# Cluster 211  ::  "|life|great|sense|true|self|god|nature|meaning|reality|greatest|faith|truth|values|spirit|concept
# Cluster 212  ::  sold|owned|bought|owner|estate|owners|acquired
# Cluster 213  ::  armed|captured|attacked|fighters|enemy
# Cluster 214  ::  gun|assault|guns
# Cluster 215  ::  anti|supporters|protest|rally|protests|protesters|activists
# Cluster 216  ::  relations|cooperation|ties|bilateral
# Cluster 217  ::  bush|clinton|obama|mccain|gore|kerry
# Cluster 218  ::  â|1992|1991|1990|1989|1988|1986|1987|1984|1980|1985|1979|1983|1982|1981|1972|1975|1974|1976
# Cluster 219  ::  sales|quarter|net|profit|earnings|losses|revenue|volume|gains|profits|posted
# Cluster 220  ::  years|during|since|end|early|months|following|late|began|ago|weeks|period|reached|continued|previous|ended|followed|beginning|starting|completed|ending|prior|extended|mid
# Cluster 221  ::  e|phone|mail|telephone|communications|mobile
# Cluster 222  ::  aid|mission|emergency|protection|relief|assistance|humanitarian
# Cluster 223  ::  recent|despite|seen|strong|showed|latest|attention|figures|concerns|concern|amid|signs|showing|marked|weak
# Cluster 224  ::  sex|sexual|abuse|behavior
# Cluster 225  ::  rule|constitution|ruled|regime|constitutional
# Cluster 226  ::  growth|increase|annual|demand|increased|increasing|boost|forecast|output
# Cluster 227  ::  long|line|point|field|short|middle|course|toward|range|moving|wide|speed|beyond|section|towards|continues|setting|direction|edge|distance|reaching|broad|passing|path
# Cluster 228  ::  according|report|reported|agency|reports|associated|sources|confirmed|declined|census|contributed|bureau|statistics|cited|citing|estimates
# Cluster 229  ::  small|large|largest|heavy|size|huge|giant|larger|smaller
# Cluster 230  ::  first|second|third|single|fourth|fifth|overall|sixth|seventh|eighth
# Cluster 231  ::  arab|turkey|egypt|lebanon|turkish|syria|sudan|lebanese
# Cluster 232  ::  -|'|--
# Cluster 233  ::  offer|offered|consider|fair|approval|decisions|considering|conduct|delay|contracts|formal|options|option|deals|proposals
# Cluster 234  ::  temple
# Cluster 235  ::  law|act|rules|laws|acts
# Cluster 236  ::  race|event|events|olympic|olympics|medal
# Cluster 237  ::  ford|engine|electric|auto|motor|gm
# Cluster 238  ::  music|album|band|song|rock|songs|producer|artists|artist|musical|singer|dance|pop
# Cluster 239  ::  study|experts|scientists|researchers
# Cluster 240  ::  cause|threat|mass|prevent|avoid|fear|threatened|fears|dangerous|wave|destruction|strikes|threats|escape|widespread
# Cluster 241  ::  peace|talks|agreement|negotiations|treaty|accord
# Cluster 242  ::  model|models
# Cluster 243  ::  due|further|results|problems|result|pressure|serious|changes|risk|conditions|significant|effect|positive|impact|lack|initial|activity|failure|normal|recovery|effects|scale|reduced|continuing|negative|phase
# Cluster 244  ::  day|next|days|night|hours|opening|hour|weekend|trip|christmas|begins|holiday|starts|brief|schedule|pre
# Cluster 245  ::  rose|fell|yen|cents|dropped|gained|falling|dow
# Cluster 246  ::  2008|2007|2010|2009|2011|2012|2013|debut|uk|edition|#
# Cluster 247  ::  card|file|cards
# Cluster 248  ::  area|town|areas|village|cities|towns|villages|districts
# Cluster 249  ::  party|election|opposition|elections|parliament|presidential|ruling|coalition|cabinet|seats|parliamentary|speaker|electoral|labour
# Cluster 250  ::  rights|human|civil|freedom|immigration|gay
# Cluster 251  ::  that|be|not|no|can|may|because|any|without|done|instead|rather|means|either|probably|longer|cannot|matter|actually|simply|appear|mean|follow|safe|except|meant|therefore|easily|otherwise|supposed
# Cluster 252  ::  kong|hong|asian|singapore|yuan|shanghai|mainland
# Cluster 253  ::  style|fine|stone|piece|pieces|glass
# Cluster 254  ::  0|vs.|v
# Cluster 255  ::  airlines|airline
# Cluster 256  ::  state|district|council|governor|administrative|provincial
# Cluster 257  ::  bc
# Cluster 258  ::  award|awards|prize|awarded
# Cluster 259  ::  b|c
# Cluster 260  ::  airport|port|railway
# Cluster 261  ::  exports|goods|export
# Cluster 262  ::  kim|chen|li
# Cluster 263  ::  rice|agriculture|agricultural
# Cluster 264  ::  bond|bonds|treasury|traded
# Cluster 265  ::  treatment|patients|doctors|treated
# Cluster 266  ::  games|final|cup|match|championship|tournament|matches|championships|champions|finals|singles|winners
# Cluster 267  ::  israel|israeli|palestinian|gaza|palestinians|hamas
# Cluster 268  ::  economy|inflation|poverty|unemployment|recession
# Cluster 269  ::  india|pakistan|indian|sri|pakistani|lanka|khan
# Cluster 270  ::  public|local|service|services|private|employees|offering|partners|clients
# Cluster 271  ::  set|open|face|faces|faced|facing|sets|row|ends|breaking|aside
# Cluster 272  ::  visit|met|arrived|attended|attend|visited|visiting|invited
# Cluster 273  ::  expected|plan|deal|announced|plans|agreed|planned|joint|bid|proposed|approved|proposal|launch|package|expansion|expects
# Cluster 274  ::  john|george|james|william|thomas|charles|henry|louis|joseph|alexander|sir|edward
# Cluster 275  ::  capital|near|southern|northern|located|base|eastern|southeast|northwest|northeast|southwest|resort
# Cluster 276  ::  summer|spring|winter|weather|rain|wind|snow
# Cluster 277  ::  space|room|inside|floor|door|box|block|bar|foot|onto|windows|corner|filled|ring
# Cluster 278  ::  japan|japanese|korean|tokyo|greek
# Cluster 279  ::  intelligence|investigators|fbi|pentagon
# Cluster 280  ::  political|leaders|social|parties|leadership|politics|politicians
# Cluster 281  ::  store|stores|retail|chain|shop
# Cluster 282  ::  star|gold|sun|silver|bowl|golden
# Cluster 283  ::  school|college|students|education|schools|student|teacher|teachers|academic
# Cluster 284  ::  book|english|published|wrote|written|books|words|read|writing|notes|page|reading|write|letters
# Cluster 285  ::  municipality
# Cluster 286  ::  manager|martin|captain|mike|tom|bob|scott|steve|joe|jim|tony|chris|brian|kevin
# Cluster 287  ::  st.|st|saint
# Cluster 288  ::  park|hall|hill|stadium|memorial|garden
# Cluster 289  ::  county|georgia|virginia|carolina|ohio|fort|columbia|illinois
# Cluster 290  ::  high|level|highest|levels|degree|weight|grade|maximum
# Cluster 291  ::  technology|systems|developed|designed|design|advanced|tech|engineering
# Cluster 292  ::  ceremony|anniversary
# Cluster 293  ::  banks|credit|debt|loans|loan
# Cluster 294  ::  defense|offensive|defence|defensive
# Cluster 295  ::  hotel|streets|neighborhood|downtown|restaurant|apartment
# Cluster 296  ::  prison|jail|sentence
# Cluster 297  ::  el|del
# Cluster 298  ::  technical|physical|theory|scientific|analysis|knowledge|learning|purpose|understanding
# Cluster 299  ::  front|stand|seat|crowd|standing|table|heads|stood|stands|flag|laid|sitting
