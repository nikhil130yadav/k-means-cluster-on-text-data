# %%
import numpy as np # linear algebra


import os
for dirname, _, filenames in os.walk(''):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

from sklearn.cluster import KMeans
from collections import defaultdict
import io

# %%
def file_preprocess(file_name, nwords):
  '''
  function to readtext file and process it to create data for clustering
  
  RETURNS: numpy array of vector dimension and list of words
  '''
  np_arrays = []
  wordlist = []
  with io.open(file_name, mode='r', encoding='utf-8') as f:
    #print("len" , len(f.readlines()))
    for index, line in enumerate(f):
      tokens = line.split()
      wordlist.append(tokens[0])
      np_arrays.append( np.array([float(i) for i in tokens[1:]]) )

      if index == nwords:
        return np.array( np_arrays ), wordlist

  return np.array( np_arrays ), wordlist

# %%
def assign_word2cluster(word_list, cluster_labels):
  '''
  RETURNS: dict {"cluster":[words  assigend to cluster]}
  '''
  cluster_to_words = defaultdict(list)
  for index, cluster in enumerate(cluster_labels):
    cluster_to_words[ cluster ].append( word_list[index] )
  return cluster_to_words

# %%
if __name__ == "__main__":
    

  cluster_data_file = "clustering_data.txt" 

  #Number of words to analyse according to memory availability
  n_words = 3000 # Number of words to analyse according to memory availability
  reduction_factor =.1  # Amount of dimension reduction {0,1}
  n_clusters = int( n_words * reduction_factor ) # Number of clusters to make
  cluster_data, wordlist = file_preprocess(cluster_data_file, nwords = n_words)
  
  kmeans_model = KMeans(init='k-means++', n_clusters=n_clusters, n_init=15,random_state=1,max_iter=500,verbose=0)
  kmeans_model.fit(cluster_data)

  cluster_labels  = kmeans_model.labels_ #returns all cluster number assigned to each word respectively
  cluster_to_words  = assign_word2cluster(wordlist, cluster_labels)
  #saving output in outut.text file
  with io.open("output.txt",mode='w+',encoding="UTF-8") as file:
    for key in sorted(cluster_to_words.keys()) :
        file.writelines("Cluster "+str(key) +" :: "+ "|".join( k for k in cluster_to_words[key])+"\n")
        print("Cluster "+str(key) , " :: " , "|".join( k for k in cluster_to_words[key]))
    file.close()
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 21141.321435687863
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 20051.30729701807
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19755.57911736624
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19644.057167849358
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 19603.977237930783
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 19586.397251971917
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 19579.48179633955
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 19569.77643192034
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 19562.50437784339
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 19557.802172445827
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 19556.148370318224
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 19556.148370318224
# center shift 0.000000e+00 within tolerance 3.377013e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 21176.174959395277
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 20197.138394935962
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19909.038338372113
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19776.32180426039
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 19706.457216685187
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 19672.501982676786
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 19650.10719606603
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 19634.993967285296
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 19629.43702173824
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 19626.60060149636
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 19626.14103099172
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 19626.14103099172
# center shift 0.000000e+00 within tolerance 3.377013e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 20857.65815528223
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 19921.772735724044
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19704.404531362354
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19636.843053346875
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 19593.54705546452
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 19576.426313091302
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 19563.877141668065
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 19559.735042170738
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 19559.046251011874
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 19559.046251011874
# center shift 0.000000e+00 within tolerance 3.377013e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 21163.08152489864
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 20126.885006137476
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19899.88244613942
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19803.911881405027
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 19736.454136172837
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 19710.44596995721
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 19698.067673928912
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 19693.599665276743
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 19691.439186710213
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 19687.157176193417
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 19682.503908581784
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 19680.102817941042
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 19680.102817941042
# center shift 0.000000e+00 within tolerance 3.377013e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 21136.584907106626
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 20081.88860846015
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19857.46821348146
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19762.931601791093
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 19715.2892024141
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 19681.12962225768
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 19656.727842690652
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 19643.13612486733
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 19632.78021229174
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 19626.618254015295
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 